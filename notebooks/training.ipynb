# %% [markdown]
# # Model training notebook

# %%
# !pip install transformers
# !pip install datasets

# %%
# !git clone https://github.com/hopl1t/frankenbert.git
# Out:
# Cloning into 'frankenbert'...
# remote: Enumerating objects: 122, done.
# remote: Counting objects: 100% (122/122), done.
# remote: Compressing objects: 100% (91/91), done.
# remote: Total 122 (delta 58), reused 74 (delta 25), pack-reused 0
# Receiving objects: 100% (122/122), 275.37 KiB | 3.67 MiB/s, done.
# Resolving deltas: 100% (58/58), done.

# %%
import os
os.chdir('frankenbert')
# !git checkout nir
from trainer import *
import utils
# Out:
# Branch 'nir' set up to track remote branch 'nir' from 'origin'.
# Switched to a new branch 'nir'

# %%
CAUSAL_DIR = '/content/drive/MyDrive/NLP_project/trained_models/causal'
MLM_DIR = '/content/drive/MyDrive/NLP_project/trained_models/mlm'

# %% [markdown]
# ## Train models

# %% [markdown]
# ### Causal

# %%
# !python trainer.py -m distilgpt2 -t causal -d wikitext,wikitext-2-raw-v1 -s /content/drive/MyDrive/NLP_project/trained_models/causal -e 4 -cn text -l /content/drive/MyDrive/NLP_project/trained_models/causal/logs
# Out:
# Downloading: 8.33kB [00:00, 7.77MB/s]
# Downloading: 5.83kB [00:00, 5.13MB/s]
# ...
# Downloading: 100% 4.72M/4.72M [00:01<00:00, 3.18MB/s]
# Dataset wikitext downloaded and prepared to /root/.cache/huggingface/datasets/wikitext/wikitext-2-raw-v1/1.0.0/aa5e094000ec7afeb74c3be92c88313cd6f132d564c7effd961c10fd47c76f20. Subsequent calls will reuse this data.
# Downloading: 100% 762/762 [00:00<00:00, 574kB/s]
# Downloading: 100% 1.04M/1.04M [00:00<00:00, 1.14MB/s]
# Downloading: 100% 456k/456k [00:00<00:00, 631kB/s]
# Downloading: 100% 1.36M/1.36M [00:01<00:00, 1.22MB/s]
#  #0:   0% 0/3 [00:00<?, ?ba/s]
#  #0:  33% 1/3 [00:00<00:00,  2.93ba/s]
#  #0: 100% 3/3 [00:00<00:00,  4.38ba/s]
#
#  #1: 100% 3/3 [00:00<00:00,  4.37ba/s]
#  #0:   0% 0/19 [00:00<?, ?ba/s]
#  #1:   0% 0/19 [00:00<?, ?ba/s]
#  #0:   5% 1/19 [00:00<00:06,  2.91ba/s]
#  #0:  16% 3/19 [00:00<00:05,  3.14ba/s]
#  #0:  21% 4/19 [00:01<00:04,  3.19ba/s]
#  #0:  26% 5/19 [00:01<00:04,  3.34ba/s]
# ...

# %%
with open('/content/drive/MyDrive/NLP_project/trained_models/causal/logs/distilgpt2_eval_2109071909.pkl', 'rb') as f:
    causal_eval = pickle.load(f)
with open('/content/drive/MyDrive/NLP_project/trained_models/causal/logs/distilgpt2_metrics_2109071909.pkl', 'rb') as f:
    causal_metrics = pickle.load(f) 
print('train loss:\t', causal_metrics[2]['train_loss'])
print('eval loss:\t', causal_eval['eval_loss'])
print('Perplexity:\t38.01')
# Out:
# train loss:	 3.6482167901804843
# eval loss:	 3.6379740238189697
# Perplexity:	38.01

# %%
# !python trainer.py -m distilgpt2 -t causal -d tiny_shakespeare -s /content/drive/MyDrive/NLP_project/trained_models/causal -e 4 -cn text -l /content/drive/MyDrive/NLP_project/trained_models/causal/logs
# Out:
# Downloading: 3.73kB [00:00, 3.35MB/s]
# Downloading: 1.90kB [00:00, 1.96MB/s]
# Using custom data configuration default
# ...
# Downloading: 1.12MB [00:00, 22.0MB/s]
# Dataset tiny_shakespeare downloaded and prepared to /root/.cache/huggingface/datasets/tiny_shakespeare/default/1.0.0/b5b13969f09fe8707337f6cb296314fbe06960bd9a868dca39e713e163d27b5e. Subsequent calls will reuse this data.
# num_proc must be <= 1. Reducing num_proc to 1 for dataset of size 1.
#   0% 0/1 [00:00<?, ?ba/s]Token indices sequence length is longer than the specified maximum sequence length for this model (301966 > 1024). Running this sequence through the model will result in indexing errors
# 100% 1/1 [00:00<00:00,  1.12ba/s]
# num_proc must be <= 1. Reducing num_proc to 1 for dataset of size 1.
# 100% 1/1 [00:00<00:00, 23.76ba/s]
# num_proc must be <= 1. Reducing num_proc to 1 for dataset of size 1.
# 100% 1/1 [00:00<00:00, 24.27ba/s]
# num_proc must be <= 1. Reducing num_proc to 1 for dataset of size 1.
# ...

# %%
with open('/content/drive/MyDrive/NLP_project/trained_models/causal/logs/distilgpt2_eval_2109072009.pkl', 'rb') as f:
    causal_eval = pickle.load(f)
with open('/content/drive/MyDrive/NLP_project/trained_models/causal/logs/distilgpt2_metrics_2109072009.pkl', 'rb') as f:
    causal_metrics = pickle.load(f) 
print('train loss:\t', causal_metrics[2]['train_loss'])
print('eval loss:\t', causal_eval['eval_loss'])
print('Perplexity:\t38.25')
# Out:
# train loss:	 3.87781785867982
# eval loss:	 3.6442084312438965
# Perplexity:	38.25

# %%
# Shakespeare overfit
# !python trainer.py -m distilgpt2 -t causal -d tiny_shakespeare -s /content/drive/MyDrive/NLP_project/trained_models/causal -e 10 -cn text -l /content/drive/MyDrive/NLP_project/trained_models/causal/logs
# Out:
# Downloading: 3.73kB [00:00, 3.83MB/s]
# Downloading: 1.90kB [00:00, 2.22MB/s]
# Using custom data configuration default
# ...
# Downloading: 1.12MB [00:00, 27.0MB/s]
# Dataset tiny_shakespeare downloaded and prepared to /root/.cache/huggingface/datasets/tiny_shakespeare/default/1.0.0/b5b13969f09fe8707337f6cb296314fbe06960bd9a868dca39e713e163d27b5e. Subsequent calls will reuse this data.
# Downloading: 100% 762/762 [00:00<00:00, 688kB/s]
# Downloading: 100% 1.04M/1.04M [00:00<00:00, 7.41MB/s]
# Downloading: 100% 456k/456k [00:00<00:00, 4.20MB/s]
# Downloading: 100% 1.36M/1.36M [00:00<00:00, 8.00MB/s]
# num_proc must be <= 1. Reducing num_proc to 1 for dataset of size 1.
#   0% 0/1 [00:00<?, ?ba/s]Token indices sequence length is longer than the specified maximum sequence length for this model (301966 > 1024). Running this sequence through the model will result in indexing errors
# 100% 1/1 [00:00<00:00,  1.15ba/s]
# num_proc must be <= 1. Reducing num_proc to 1 for dataset of size 1.
# ...

# %%
with open('/content/drive/MyDrive/NLP_project/trained_models/causal/logs/distilgpt2_eval_2109091009.pkl', 'rb') as f:
    causal_eval = pickle.load(f)
with open('/content/drive/MyDrive/NLP_project/trained_models/causal/logs/distilgpt2_metrics_2109091009.pkl', 'rb') as f:
    causal_metrics = pickle.load(f) 
print('train loss:\t', causal_metrics[2]['train_loss'])
print('eval loss:\t', causal_eval['eval_loss'])
print('Perplexity:\t38.25')
# Out:
# train loss:	 3.6751833537473515
# eval loss:	 3.5438270568847656
# Perplexity:	38.25

# %%
# !python trainer.py -m distilgpt2 -t causal -d stas/openwebtext-10k -s /content/drive/MyDrive/NLP_project/trained_models/causal -e 4 -cn text -l /content/drive/MyDrive/NLP_project/trained_models/causal/logs
# Out:
# Reusing dataset openwebtext10k (/root/.cache/huggingface/datasets/openwebtext10k/plain_text/1.0.0/3a8df094c671b4cb63ed0b41f40fb3bd855e9ce2e3765e5df50abcdfb5ec144b)
# Loading cached split indices for dataset at /root/.cache/huggingface/datasets/openwebtext10k/plain_text/1.0.0/3a8df094c671b4cb63ed0b41f40fb3bd855e9ce2e3765e5df50abcdfb5ec144b/cache-55043b2ed776c9a2.arrow and /root/.cache/huggingface/datasets/openwebtext10k/plain_text/1.0.0/3a8df094c671b4cb63ed0b41f40fb3bd855e9ce2e3765e5df50abcdfb5ec144b/cache-0515f33fdfee80f0.arrow
# Downloading: 100% 762/762 [00:00<00:00, 693kB/s]
# Downloading: 100% 1.04M/1.04M [00:00<00:00, 2.48MB/s]
# Downloading: 100% 456k/456k [00:00<00:00, 1.34MB/s]
# Downloading: 100% 1.36M/1.36M [00:00<00:00, 3.22MB/s]
#  #0:   0% 0/5 [00:00<?, ?ba/s]
# ...

# %%
with open('/content/drive/MyDrive/NLP_project/trained_models/causal/logs/distilgpt2_eval_2109082209.pkl', 'rb') as f:
    causal_eval = pickle.load(f)
with open('/content/drive/MyDrive/NLP_project/trained_models/causal/logs/distilgpt2_metrics_2109082209.pkl', 'rb') as f:
    causal_metrics = pickle.load(f) 
print('train loss:\t', causal_metrics[2]['train_loss'])
print('eval loss:\t', causal_eval['eval_loss'])
# Out:
# train loss:	 3.63646567679907
# eval loss:	 3.5619332790374756

# %% [markdown]
# ### MLM

# %%
# !python trainer.py -m distilroberta-base -t MLM -d wikitext,wikitext-2-raw-v1 -s /content/drive/MyDrive/NLP_project/trained_models/mlm -e 4 -cn text -l /content/drive/MyDrive/NLP_project/trained_models/mlm/logs
# Out:
# Traceback (most recent call last):
#   File "<frozen importlib._bootstrap>", line 677, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 728, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/usr/lib/python3.7/_compression.py", line 33, in <module>
#     class DecompressReader(io.RawIOBase):
#   File "/usr/lib/python3.7/_compression.py", line 33, in DecompressReader
#     class DecompressReader(io.RawIOBase):
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "trainer.py", line 4, in <module>
#     from transformers import AutoModelForCausalLM
#   File "/usr/local/lib/python3.7/dist-packages/transformers/__init__.py", line 43, in <module>
#     from . import dependency_versions_check
#   File "/usr/local/lib/python3.7/dist-packages/transformers/dependency_versions_check.py", line 17, in <module>
# ...

# %%
with open('/content/drive/MyDrive/NLP_project/trained_models/mlm/logs/distilroberta-base_eval_2109080109.pkl', 'rb') as f:
    causal_eval = pickle.load(f)
with open('/content/drive/MyDrive/NLP_project/trained_models/mlm/logs/distilroberta-base_metrics_2109080109.pkl', 'rb') as f:
    causal_metrics = pickle.load(f) 
print('train loss:\t', causal_metrics[2]['train_loss'])
print('eval loss:\t', causal_eval['eval_loss'])
print('Perplexity:\t6.25')
# Out:
# train loss:	 2.003205436522626
# eval loss:	 1.8319644927978516
# Perplexity:	6.25

# %%
# !python trainer.py -m distilroberta-base -t MLM -d tiny_shakespeare -s /content/drive/MyDrive/NLP_project/trained_models/mlm -e 4 -cn text -l /content/drive/MyDrive/NLP_project/trained_models/mlm/logs
# Out:
# Using custom data configuration default
# Reusing dataset tiny_shakespeare (/root/.cache/huggingface/datasets/tiny_shakespeare/default/1.0.0/b5b13969f09fe8707337f6cb296314fbe06960bd9a868dca39e713e163d27b5e)
# num_proc must be <= 1. Reducing num_proc to 1 for dataset of size 1.
#   0% 0/1 [00:00<?, ?ba/s]Token indices sequence length is longer than the specified maximum sequence length for this model (301968 > 512). Running this sequence through the model will result in indexing errors
# 100% 1/1 [00:00<00:00,  1.06ba/s]
# num_proc must be <= 1. Reducing num_proc to 1 for dataset of size 1.
# 100% 1/1 [00:00<00:00, 21.25ba/s]
# num_proc must be <= 1. Reducing num_proc to 1 for dataset of size 1.
# 100% 1/1 [00:00<00:00, 23.08ba/s]
# num_proc must be <= 1. Reducing num_proc to 1 for dataset of size 1.
# 100% 1/1 [00:00<00:00,  3.73ba/s]
# num_proc must be <= 1. Reducing num_proc to 1 for dataset of size 1.
# 100% 1/1 [00:00<00:00, 62.34ba/s]
# ...

# %%
with open('/content/drive/MyDrive/NLP_project/trained_models/mlm/logs/distilroberta-base_eval_2109080209.pkl', 'rb') as f:
    causal_eval = pickle.load(f)
with open('/content/drive/MyDrive/NLP_project/trained_models/mlm/logs/distilroberta-base_metrics_2109080209.pkl', 'rb') as f:
    causal_metrics = pickle.load(f) 
print('train loss:\t', causal_metrics[2]['train_loss'])
print('eval loss:\t', causal_eval['eval_loss'])
print('Perplexity:\t11.82')
# Out:
# train loss:	 2.768323840125132
# eval loss:	 2.4698333740234375
# Perplexity:	11.82

# %%
# !python trainer.py -m distilroberta-base -t MLM -d stas/openwebtext-10k -s /content/drive/MyDrive/NLP_project/trained_models/mlm -e 4 -cn text -l /content/drive/MyDrive/NLP_project/trained_models/mlm/logs
# Out:
# Reusing dataset openwebtext10k (/root/.cache/huggingface/datasets/openwebtext10k/plain_text/1.0.0/3a8df094c671b4cb63ed0b41f40fb3bd855e9ce2e3765e5df50abcdfb5ec144b)
# Loading cached split indices for dataset at /root/.cache/huggingface/datasets/openwebtext10k/plain_text/1.0.0/3a8df094c671b4cb63ed0b41f40fb3bd855e9ce2e3765e5df50abcdfb5ec144b/cache-55043b2ed776c9a2.arrow and /root/.cache/huggingface/datasets/openwebtext10k/plain_text/1.0.0/3a8df094c671b4cb63ed0b41f40fb3bd855e9ce2e3765e5df50abcdfb5ec144b/cache-0515f33fdfee80f0.arrow
# Loading cached processed dataset at /root/.cache/huggingface/datasets/openwebtext10k/plain_text/1.0.0/3a8df094c671b4cb63ed0b41f40fb3bd855e9ce2e3765e5df50abcdfb5ec144b/cache-b814bf9286b44a8b.arrow
# Loading cached processed dataset at /root/.cache/huggingface/datasets/openwebtext10k/plain_text/1.0.0/3a8df094c671b4cb63ed0b41f40fb3bd855e9ce2e3765e5df50abcdfb5ec144b/cache-e8349b65807ff9c4.arrow
# ...

# %%
with open('/content/drive/MyDrive/NLP_project/trained_models/mlm/logs/distilroberta-base_eval_2109081809.pkl', 'rb') as f:
    causal_eval = pickle.load(f)
with open('/content/drive/MyDrive/NLP_project/trained_models/mlm/logs/distilroberta-base_metrics_2109081809.pkl', 'rb') as f:
    causal_metrics = pickle.load(f) 
print('train loss:\t', causal_metrics[2]['train_loss'])
print('eval loss:\t', causal_eval['eval_loss'])
print('Perplexity:\t5.84')
# Out:
# train loss:	 1.9583107715080206
# eval loss:	 1.7651718854904175
# Perplexity:	5.84

# %% [markdown]
# ### Demonstrations

# %%
wiki_model = torch.load('./distilgpt2_wikitext_2109071009.pkl')

# %%
# this can now also be loaded from a pickle
model_name = 'distilgpt2'
tokenizer = AutoTokenizer.from_pretrained(model_name, use_fast=True)

# %%
utils.generate(model, 'Hello I am very', tokenizer)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# ...

# %%
utils.predict_next(model, 'Hello I am very', tokenizer)

# %%
# !python trainer.py -m distilroberta-base -t MLM -d wikitext,wikitext-2-raw-v1 -s ./ -e 1

# %%
model = torch.load('./distilroberta-base_wikitext_2108281608.pkl')
with open('./distilroberta-base_tokenizer_2108281608.pkl', 'rb') as f:
    tokenizer = pickle.load(f)

# %%
predictions = utils.mlm(model, f'Not since {tokenizer.mask_token} did the english went to war', tokenizer)
for p in predictions:
    print(p)
# Out:
# 0.158:	Not since == 1914 == did the english went to war
# 0.0808:	Not since == 1917 == did the english went to war
# 0.0657:	Not since == 1918 == did the english went to war
# 0.0405:	Not since == 1945 == did the english went to war
# 0.0397:	Not since == war == did the english went to war

# %%
wiki_model = torch.load('./distilgpt2_wikitext_2109071009.pkl')
franken = frankenstein(wiki_model, shake_model, [1,2,3,4])
print(generate(franken, 'It was in the', tokenizer, top_k=60, temp=1.9))
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# It was in the process, if any doubt I owe you or whatever she said when you had the answer - you do. There you will get nothing and this should be done as well. There does go ahead and then the day of this sentence appears as soon as practicable – in an hour that the reader may know the truth. No trouble from an instant at this stage in her sentence the same moment in his first letter was printed. All is well the writer has written for each of these parts : I say this now is all too soon " - the same letter she written several of's own, to whom to meet and receive she may yet continue these four statements " before going forward "
# ...

# %% [markdown]
# ## testing

# %%
# !python trainer.py -m distilroberta-base -t MLM -d wikitext,wikitext-2-raw-v1 -s /content/drive/MyDrive/NLP_project/trained_models/mlm -e 1 -cn text

# %%
# !python trainer.py -m distilroberta-base -t MLM -d tiny_shakespeare -s /content/drive/MyDrive/NLP_project/trained_models/mlm -e 1 -cn text

# %%
# TODO: build frankenbert for roberta

# %%
# !python trainer.py -m distilroberta-base -t MLM -d tiny_shakespeare -s ./ -e 1 -cn text
# Out:
# Using custom data configuration default
# Reusing dataset tiny_shakespeare (/root/.cache/huggingface/datasets/tiny_shakespeare/default/1.0.0/b5b13969f09fe8707337f6cb296314fbe06960bd9a868dca39e713e163d27b5e)
# HTTPSConnectionPool(host='huggingface.co', port=443): Max retries exceeded with url: /distilroberta-base/resolve/main/config.json (Caused by SSLError(SSLCertVerificationError("hostname 'huggingface.co' doesn't match 'moon-staging.huggingface.co'")))
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py", line 600, in urlopen
#     chunked=chunked)
#   File "/usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py", line 343, in _make_request
#     self._validate_conn(conn)
#   File "/usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py", line 839, in _validate_conn
#     conn.connect()
#   File "/usr/local/lib/python3.7/dist-packages/urllib3/connection.py", line 364, in connect
# ...

# %%
def generate(model, prompt, tokenizer, top_k=60, temp=1):
    device = model.device
    inputs = tokenizer.encode(prompt, add_special_tokens=False, return_tensors="pt").to(device)
    prompt_length = len(tokenizer.decode(inputs[0], skip_special_tokens=True, clean_up_tokenization_spaces=True))
    outputs = model.generate(inputs, max_length=250, do_sample=True, top_p=0.95, top_k=top_k, temperature=temp)
    generated = prompt + tokenizer.decode(outputs[0])[prompt_length:]
    return generated
